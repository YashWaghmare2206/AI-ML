# %% [markdown]
# # 01_Multivariable_Functions
#
# Until now, our functions had **one input**:
#
# ![image.png](attachment:acceea90-7c9d-424b-bc22-6bc3c4a04ade.png)
#
# Input:
#
# * (x)
#
# Output:
#
# * one value
#
# ---
#
# ## What is a Multivariable Function?
#
# A multivariable function has **more than one input variable**.
#
# Example:
#
# ![image.png](attachment:b82ed634-05bc-4c54-9af1-6490fdbc19f8.png)
#
# Inputs:
#
# * (x)
# * (y)
#
# Output:
#
# * one value
#
# ---
#
# ## Example
#
# Let:
#
# ![image.png](attachment:b144be7a-7c2e-4a2d-9ab2-5dc7af3eab23.png)
#
# ![image.png](attachment:129d414e-3de2-4a26-b2af-f88eedc8bb4d.png)
#
# ---
#
# ## Why ML Cares
#
# Machine Learning models usually have **many parameters (weights)**.
#
# Example:
#
# ![image.png](attachment:eff02e49-cc01-4d9c-babf-90fc3ab07cae.png)
#
# Notice:
#
# * Input is not a single variable.
# * Input is multiple variables.
#
# Real neural networks may have:
#
# * thousands
# * millions
# * billions
#
# of parameters.
#
# So ML optimization deals with multivariable functions almost all the time.
#
# ---
#
# ## Visualization
#
# Single variable:
#
# ![image.png](attachment:224060b5-9cad-4ce5-8e76-d5fa35481b2d.png)
#
# Graph → 2D curve.
#
# ---
#
# Multivariable:
#
# ![image.png](attachment:a519a481-c6d4-4877-923a-3c97f891d8e3.png)
#
# Graph → 3D surface.
#
# Think:
#
# * x-axis → (x)
# * y-axis → (y)
# * z-axis → function value
#
# ![image.png](attachment:d4100e49-f56f-40a8-bf44-c6c574071cf3.png)
#
# ---
#
# ## Python
#
# ```python
# def f(x, y):
#     return x**2 + y**2
#
# print(f(2, 3))
# ```
#
# Output:
#
# ```python
# 13
# ```
#
# ---
#
# ## Key Takeaway
#
# A multivariable function:
#
# ![image.png](attachment:69b7c3c8-4218-490e-9391-85be4ec85a8b.png)
#
# has multiple inputs and one output.
#
# This is the foundation for:
#
# * Partial Derivatives
# * Gradients
# * Gradient Descent
# * ML Optimization
