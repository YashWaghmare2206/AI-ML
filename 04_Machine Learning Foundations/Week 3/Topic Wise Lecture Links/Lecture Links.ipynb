# %% [markdown]
# # Classification
#
# 1. https://youtu.be/p-ltr1C7u2o?si=VpICbluwsAS-PIDc

# %% [markdown]
# # Logistic Regression
#
# 1. https://youtu.be/xuTiAW0OR40?si=CNqbwa_AWq6iDsDW

# %% [markdown]
# # Decision Boundry
#
# 1.https://youtu.be/0az8RjxLLPQ?si=UEE1l2zWaBSsIXuL

# %% [markdown]
# # Cost Function for Logistic Regression
#
# 1. https://youtu.be/vq4Ie5xWhww?si=eJ7YBH_4UqvNjWmb
# 2. https://youtu.be/YkTcK_LXAxw?si=-c62WCZRBgD2GVi-

# %% [markdown]
# ## Gradient Descent Implementation Logistic
#
# 1. https://youtu.be/6SZUnXEHCns?si=H6ZlWXh-IUEcr7Bb

# %% [markdown]
# ## Overfitting and method to tackle it
#
# 1. https://youtu.be/8upNQi-40Q8?si=DpCEewEllVx91EsS
# 2. https://youtu.be/1kgcON0Eauc?si=JuNgxdc4zKziFkOU

# %% [markdown]
# ## Cost Function with Regularization
#
# 1. https://youtu.be/NIiZZY7nlfU?si=heOI15Ft-9mbGTek

# %% [markdown]
# ## Regularized Linear Regression
#
# 1. https://youtu.be/jhrrw8Iuus0?si=zik4C_jdFa2C3WM

# %% [markdown]
# ## Regularized Logistic Regression
#
# 1. https://youtu.be/NhZXRzH2y-E?si=w2EmQvNALf0qOj8R
