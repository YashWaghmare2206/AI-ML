# %%
import numpy as np
import pandas as pd

# %%
# Dataset

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

# %%
# Initialization

w = 0
b = 0
learning_rate = 0.01
itr = 10000
m = len(x) # Number of rows or data points in total

# %%
def predict(w, x, b):
    return w * x + b

# %%
def J_func(y_hat, y, m):
    return np.sum((y_hat - y) ** 2) / (2 * m)

# %%
def gradient_w(y_hat, y, x, m):
    return np.sum((y_hat - y) * x) / m

def gradient_b(y_hat, y, m):
    return np.sum(y_hat - y) / m

# %%
for i in range(itr):

    y_hat = predict(w , x , b)
    J = J_func(y_hat , y , m)

    if i % 100 == 0:
        print(J)     # Print Cost Function at evry 10 iteration

    d_w = gradient_w(y_hat , y , x , m)
    d_b = gradient_b(y_hat , y , m)

    w = w - learning_rate * d_w
    b = b - learning_rate * d_b


print(f"w : {w} ")
print(f"b : {b} ")
# Out:
# 44.5
# 0.33484530238900156
# 0.23871881053788221
# 0.17018805455749356
# 0.12133092423174592
# 0.08649956786453847
# 0.06166750387939588
# 0.04396416223339723
# 0.03134304843381647
# 0.022345170139016067
# 0.015930378616359205
# 0.011357128242108968
# 0.0080967543216614
# 0.005772359803271114
# 0.004115246230119309
# 0.00293385237782898
# 0.0020916099046260532
# 0.0014911561420711261
# 0.0010630790354925555
# 0.0007578931567381651
# 0.0005403192216695332
# 0.00038520582843372755
# 0.0002746219721756856
# 0.00019578423283030227
# 0.0001395790202847554
# 9.950904943677063e-05
# 7.094225836812916e-05
# 5.0576345074709534e-05
# 3.605702355628601e-05
# 2.570586992433478e-05
# 1.8326297719368724e-05
# 1.3065233313929326e-05
# 9.314501169919244e-06
# 6.64051915184592e-06
# 4.734176720964015e-06
# 3.375101963087397e-06
# 2.4061867422027758e-06
# 1.715425104686252e-06
# 1.22296546572033e-06
# 8.718798193271443e-07
# 6.215828988297811e-07
# 4.431405470717808e-07
# 3.159249471451914e-07
# 2.252300605042663e-07
# 1.605716187119924e-07
# 1.1447514900079496e-07
# 8.161193020233411e-08
# 5.818299613069023e-08
# 4.147997762534443e-08
# 2.9572016881383267e-08
# 2.108256157528697e-08
# 1.503023633331663e-08
# 1.0715396391878649e-08
# 7.639249130198844e-09
# 5.446193975345835e-09
# 3.8827152133508036e-09
# 2.7680757417384498e-09
# 1.9734239807422237e-09
# 1.4068987163014237e-09
# 1.0030100056087706e-09
# 7.150685828380529e-10
# 5.097886116151162e-10
# 3.6343986404410446e-10
# 2.5910452247198153e-10
# 1.8472149097473785e-10
# 1.3169214069418112e-10
# 9.388631410249345e-11
# 6.693368282518032e-11
# 4.77185406509808e-11
# 3.401962996583018e-11
# 2.425336582152596e-11
# 1.7290774600666957e-11
# 1.2326985391031174e-11
# 8.788187477184473e-12
# 6.265298181680647e-12
# 4.466673182178235e-12
# 3.184392623481549e-12
# 2.2702257296853667e-12
# 1.6184954157575473e-12
# 1.1538620923016143e-12
# 8.226144566032577e-13
# 5.864605044640122e-13
# 4.181009953874845e-13
# 2.980736829575427e-13
# 2.1250348985253695e-13
# 1.5149855798469752e-13
# 1.0800675841669538e-13
# 7.700046750109194e-14
# 5.4895379624001576e-14
# 3.913616140767915e-14
# 2.7901057394744465e-14
# 1.9891296712846948e-14
# 1.4180956460537543e-14
# 1.0109925405976165e-14
# 7.207595158409733e-15
# 5.1384581744753805e-15
# 3.663323363321518e-15
# 2.611666304111839e-15
# 1.8619161005039827e-15
# 1.327402210971815e-15
# w : 2.000000028244607
# b : 2.9999998980280047
